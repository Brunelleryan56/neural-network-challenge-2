# %% [markdown]
# ## Part 1: Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras import layers

#  Import and read the attrition data
attrition_df = pd.read_csv('https://static.bc-edx.com/ai/ail-v-1-0/m19/lms/datasets/attrition.csv')
attrition_df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  HourlyRate  \
# 0          2  Life Sciences                        2          94
# 1          1  Life Sciences                        3          61
# 2          2          Other                        4          92
# 3          4  Life Sciences                        4          56
# 4          1        Medical                        1          40
#
#    JobInvolvement  ...  PerformanceRating RelationshipSatisfaction  \
# 0               3  ...                  3                        1
# 1               2  ...                  4                        4
# 2               2  ...                  3                        2
# 3               3  ...                  3                        3
# 4               3  ...                  3                        4
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                 8                      0               1
# 1                 1                10                      3               3
# 2                 0                 7                      3               3
# 3                 0                 8                      3               3
# 4                 1                 6                      3               3
#
#    YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                   4                        0
# 1              10                   7                        1
# 2               0                   0                        0
# 3               8                   7                        3
# 4               2                   2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 27 columns]

# %%
# Determine the number of unique values in each column.
attrition_df.nunique()
# Out:
# Age                         43
# Attrition                    2
# BusinessTravel               3
# Department                   3
# DistanceFromHome            29
# Education                    5
# EducationField               6
# EnvironmentSatisfaction      4
# HourlyRate                  71
# JobInvolvement               4
# JobLevel                     5
# JobRole                      9
# JobSatisfaction              4
# MaritalStatus                3
# NumCompaniesWorked          10
# OverTime                     2
# PercentSalaryHike           15
# PerformanceRating            2
# RelationshipSatisfaction     4
# StockOptionLevel             4
# TotalWorkingYears           40
# TrainingTimesLastYear        7
# WorkLifeBalance              4
# YearsAtCompany              37
# YearsInCurrentRole          19
# YearsSinceLastPromotion     16
# YearsWithCurrManager        18
# dtype: int64

# %%
# Create y_df with the Attrition and Department columns
y_df = attrition_df[['Attrition', 'Department']]
y_df.head()
# Out:
#   Attrition              Department
# 0       Yes                   Sales
# 1        No  Research & Development
# 2       Yes  Research & Development
# 3        No  Research & Development
# 4        No  Research & Development

# %%
# Create a list of at least 10 column names to use as X data
X = ['Age', 'BusinessTravel', 'DistanceFromHome', 'Education', 'HourlyRate',
     'EnvironmentSatisfaction', 'PercentSalaryHike', 'YearsAtCompany', 'YearsSinceLastPromotion', 'OverTime']


# Create X_df using your selected columns
X_df = attrition_df[['Age', 'BusinessTravel', 'DistanceFromHome', 'Education', 'HourlyRate',
     'EnvironmentSatisfaction', 'PercentSalaryHike', 'YearsAtCompany', 'YearsSinceLastPromotion', 'OverTime']]

# Show the data types for X_df
X_df.dtypes
# Out:
# Age                         int64
# BusinessTravel             object
# DistanceFromHome            int64
# Education                   int64
# HourlyRate                  int64
# EnvironmentSatisfaction     int64
# PercentSalaryHike           int64
# YearsAtCompany              int64
# YearsSinceLastPromotion     int64
# OverTime                   object
# dtype: object

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_df, y_df, test_size=0.2, random_state=42)

# %%
# Convert your X data to numeric data types however you see fit
# Add new code cells as necessary
X_numeric = pd.get_dummies(X_df, columns=['BusinessTravel', 'OverTime'], drop_first=True)
X_numeric.dtypes
# Out:
# Age                                 int64
# DistanceFromHome                    int64
# Education                           int64
# HourlyRate                          int64
# EnvironmentSatisfaction             int64
# PercentSalaryHike                   int64
# YearsAtCompany                      int64
# YearsSinceLastPromotion             int64
# BusinessTravel_Travel_Frequently     bool
# BusinessTravel_Travel_Rarely         bool
# OverTime_Yes                         bool
# dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X_numeric, y_df, test_size=0.2, random_state=42)

# %%
# Create a StandardScaler
scaler = StandardScaler()

# Fit the StandardScaler to the training data
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Scale the training and testing data

X_train_scaled
# Out:
# array([[-1.38855944,  1.44039645, -0.86335572, ..., -0.49041445,
#          0.63904869, -0.63641018],
#        [-2.04073779, -0.52269928, -0.86335572, ..., -0.49041445,
#         -1.56482598, -0.63641018],
#        [-0.84507748,  1.31770296, -0.86335572, ..., -0.49041445,
#          0.63904869, -0.63641018],
#        ...,
#        [-1.60595222, -0.76808624,  1.06322176, ...,  2.03909165,
#         -1.56482598,  1.57131364],
#        [-0.84507748,  0.45884859, -0.86335572, ..., -0.49041445,
#          0.63904869,  1.57131364],
#        [ 1.43754676, -0.03192534,  0.09993302, ..., -0.49041445,
#          0.63904869,  1.57131364]])

# %%
# Create a OneHotEncoder for the Department column
from sklearn.preprocessing import OneHotEncoder
department_encoder = OneHotEncoder(sparse_output=False, drop='first') # Set sparse_output=False

# Fit the encoder to the training data
department_encoder.fit(y_train[['Department']])

# Create two new variables by applying the encoder
# to the training and testing data
y_train_department_encoded = department_encoder.transform(y_train[['Department']])
y_test_department_encoded = department_encoder.transform(y_test[['Department']])

y_train_department_encoded_df = pd.DataFrame(
    y_train_department_encoded,
    columns=department_encoder.get_feature_names_out(['Department']),
    index=y_train.index
)

y_test_department_encoded_df = pd.DataFrame(
    y_test_department_encoded,
    columns=department_encoder.get_feature_names_out(['Department']),
    index=y_test.index
)

# %%
# Create a OneHotEncoder for the Attrition column
from sklearn.preprocessing import OneHotEncoder
attrition_encoder = OneHotEncoder(sparse_output=False, drop='first') # Set sparse_output=False

# Fit the encoder to the training data
attrition_encoder.fit(y_train[['Attrition']])

# Create two new variables by applying the encoder
# to the training and testing data
y_train_attrition_encoded = attrition_encoder.transform(y_train[['Attrition']])
y_test_attrition_encoded = attrition_encoder.transform(y_test[['Attrition']])

y_train_attrition_encoded_df = pd.DataFrame(
    y_train_attrition_encoded,
    columns=attrition_encoder.get_feature_names_out(['Attrition']),
    index=y_train.index
)

y_test_attrition_encoded_df = pd.DataFrame(
    y_test_attrition_encoded,
    columns=attrition_encoder.get_feature_names_out(['Attrition']),
    index=y_test.index
)

# %% [markdown]
# ## Create, Compile, and Train the Model

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.17.1

# %%
# Find the number of columns in the X training data
number_input_features = X_train_scaled.shape[1]
# Create the input layer
input_layer = tf.keras.layers.Input(shape=(number_input_features,))

# Create at least two shared layers
hidden_layer_1 = tf.keras.layers.Dense(units=10, activation='relu')(input_layer)
hidden_layer_2 = tf.keras.layers.Dense(units=6, activation='relu')(hidden_layer_1)

# %%
# Create a branch for Department
# with a hidden layer and an output layer

# Create the hidden layer
department_hidden_layer = tf.keras.layers.Dense(units=4, activation='relu')(hidden_layer_2)

# Create the output layer
department_output_layer = tf.keras.layers.Dense(
    units=y_train_department_encoded_df.shape[1],
    activation='softmax',
    name='department_output'
)(department_hidden_layer)

# %%
# Create a branch for Attrition
# with a hidden layer and an output layer

# Create the hidden layer
attrition_hidden_layer = tf.keras.layers.Dense(units=4, activation='relu')(hidden_layer_2)

# Create the output layer
attrition_output_layer = tf.keras.layers.Dense(
    units=1,
    activation='sigmoid',
    name='attrition_output'
)(attrition_hidden_layer)

# %%
# Create the model
model = tf.keras.models.Model(
    inputs=input_layer,
    outputs=[attrition_output_layer, department_output_layer]
)
# Compile the model
model.compile(
    optimizer='adam',
    loss={
        'attrition_output': 'binary_crossentropy',
        'department_output': 'categorical_crossentropy'
    },
    metrics={
        'attrition_output': 'accuracy',
        'department_output': 'accuracy'
    }
)

# Summarize the model
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 11)             │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 10)             │            120 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 6)              │             66 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 4)              │             28 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 4)              │             28 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ attrition_output (Dense)  │ (None, 1)              │              5 │ dense_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ department_output (Dense) │ (None, 2)              │             10 │ dense_2[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 257 (1.00 KB)
#  Trainable params: 257 (1.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
y_train_targets = {
    'attrition_output': y_train['Attrition'].apply(lambda x: 1 if x == 'Yes' else 0),  # Convert Yes/No to 1/0
    'department_output': y_train_department_encoded_df
}
history = model.fit(
    X_train_scaled,
    y_train_targets,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - attrition_output_accuracy: 0.6500 - attrition_output_loss: 0.6631 - department_output_accuracy: 0.4087 - department_output_loss: 0.6874 - loss: 1.3504 - val_attrition_output_accuracy: 0.7966 - val_attrition_output_loss: 0.6120 - val_department_output_accuracy: 0.6144 - val_department_output_loss: 0.6617 - val_loss: 1.2760
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - attrition_output_accuracy: 0.8347 - attrition_output_loss: 0.6010 - department_output_accuracy: 0.6302 - department_output_loss: 0.6593 - loss: 1.2603 - val_attrition_output_accuracy: 0.7966 - val_attrition_output_loss: 0.5699 - val_department_output_accuracy: 0.6610 - val_department_output_loss: 0.6520 - val_loss: 1.2270
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8289 - attrition_output_loss: 0.5616 - department_output_accuracy: 0.6868 - department_output_loss: 0.6431 - loss: 1.2045 - val_attrition_output_accuracy: 0.7966 - val_attrition_output_loss: 0.5299 - val_department_output_accuracy: 0.6695 - val_department_output_loss: 0.6440 - val_loss: 1.1819
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8384 - attrition_output_loss: 0.5202 - department_output_accuracy: 0.7104 - department_output_loss: 0.6317 - loss: 1.1519 - val_attrition_output_accuracy: 0.7966 - val_attrition_output_loss: 0.4994 - val_department_output_accuracy: 0.6695 - val_department_output_loss: 0.6377 - val_loss: 1.1478
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8293 - attrition_output_loss: 0.5011 - department_output_accuracy: 0.6968 - department_output_loss: 0.6325 - loss: 1.1337 - val_attrition_output_accuracy: 0.7966 - val_attrition_output_loss: 0.4779 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6322 - val_loss: 1.1232
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8406 - attrition_output_loss: 0.4601 - department_output_accuracy: 0.6942 - department_output_loss: 0.6261 - loss: 1.0862 - val_attrition_output_accuracy: 0.7966 - val_attrition_output_loss: 0.4650 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6275 - val_loss: 1.1074
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8389 - attrition_output_loss: 0.4357 - department_output_accuracy: 0.6855 - department_output_loss: 0.6271 - loss: 1.0629 - val_attrition_output_accuracy: 0.7966 - val_attrition_output_loss: 0.4570 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6239 - val_loss: 1.0968
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8248 - attrition_output_loss: 0.4597 - department_output_accuracy: 0.6932 - department_output_loss: 0.6121 - loss: 1.0719 - val_attrition_output_accuracy: 0.7966 - val_attrition_output_loss: 0.4508 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6212 - val_loss: 1.0882
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8349 - attrition_output_loss: 0.4237 - department_output_accuracy: 0.7064 - department_output_loss: 0.6038 - loss: 1.0275 - val_attrition_output_accuracy: 0.7966 - val_attrition_output_loss: 0.4480 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6191 - val_loss: 1.0843
# Epoch 10/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8334 - attrition_output_loss: 0.4285 - department_output_accuracy: 0.6992 - department_output_loss: 0.6061 - loss: 1.0342 - val_attrition_output_accuracy: 0.7966 - val_attrition_output_loss: 0.4431 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6179 - val_loss: 1.0777
# Epoch 11/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8416 - attrition_output_loss: 0.4121 - department_output_accuracy: 0.6915 - department_output_loss: 0.6114 - loss: 1.0239 - val_attrition_output_accuracy: 0.7966 - val_attrition_output_loss: 0.4400 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6175 - val_loss: 1.0742
# Epoch 12/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8586 - attrition_output_loss: 0.3882 - department_output_accuracy: 0.7022 - department_output_loss: 0.5977 - loss: 0.9864 - val_attrition_output_accuracy: 0.7966 - val_attrition_output_loss: 0.4371 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6171 - val_loss: 1.0712
# Epoch 13/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8262 - attrition_output_loss: 0.4325 - department_output_accuracy: 0.6920 - department_output_loss: 0.6038 - loss: 1.0361 - val_attrition_output_accuracy: 0.7966 - val_attrition_output_loss: 0.4334 - val_department_output_accuracy: 0.6695 - val_department_output_loss: 0.6170 - val_loss: 1.0673
# Epoch 14/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8343 - attrition_output_loss: 0.4113 - department_output_accuracy: 0.6835 - department_output_loss: 0.6018 - loss: 1.0129 - val_attrition_output_accuracy: 0.7966 - val_attrition_output_loss: 0.4305 - val_department_output_accuracy: 0.6695 - val_department_output_loss: 0.6177 - val_loss: 1.0650
# Epoch 15/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8366 - attrition_output_loss: 0.3970 - department_output_accuracy: 0.7224 - department_output_loss: 0.5846 - loss: 0.9816 - val_attrition_output_accuracy: 0.7966 - val_attrition_output_loss: 0.4275 - val_department_output_accuracy: 0.6695 - val_department_output_loss: 0.6178 - val_loss: 1.0619
# Epoch 16/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8380 - attrition_output_loss: 0.3941 - department_output_accuracy: 0.6820 - department_output_loss: 0.6031 - loss: 0.9970 - val_attrition_output_accuracy: 0.8093 - val_attrition_output_loss: 0.4237 - val_department_output_accuracy: 0.6610 - val_department_output_loss: 0.6182 - val_loss: 1.0583
# Epoch 17/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8399 - attrition_output_loss: 0.3944 - department_output_accuracy: 0.6989 - department_output_loss: 0.6008 - loss: 0.9951 - val_attrition_output_accuracy: 0.8178 - val_attrition_output_loss: 0.4208 - val_department_output_accuracy: 0.6610 - val_department_output_loss: 0.6182 - val_loss: 1.0554
# Epoch 18/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8359 - attrition_output_loss: 0.4091 - department_output_accuracy: 0.7065 - department_output_loss: 0.5883 - loss: 0.9979 - val_attrition_output_accuracy: 0.8051 - val_attrition_output_loss: 0.4175 - val_department_output_accuracy: 0.6568 - val_department_output_loss: 0.6181 - val_loss: 1.0516
# Epoch 19/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8650 - attrition_output_loss: 0.3602 - department_output_accuracy: 0.6960 - department_output_loss: 0.5981 - loss: 0.9581 - val_attrition_output_accuracy: 0.8220 - val_attrition_output_loss: 0.4147 - val_department_output_accuracy: 0.6568 - val_department_output_loss: 0.6184 - val_loss: 1.0495
# Epoch 20/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8655 - attrition_output_loss: 0.3523 - department_output_accuracy: 0.7116 - department_output_loss: 0.5864 - loss: 0.9389 - val_attrition_output_accuracy: 0.8220 - val_attrition_output_loss: 0.4110 - val_department_output_accuracy: 0.6568 - val_department_output_loss: 0.6191 - val_loss: 1.0466
# Epoch 21/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - attrition_output_accuracy: 0.8537 - attrition_output_loss: 0.3860 - department_output_accuracy: 0.6943 - department_output_loss: 0.5977 - loss: 0.9836 - val_attrition_output_accuracy: 0.8220 - val_attrition_output_loss: 0.4091 - val_department_output_accuracy: 0.6610 - val_department_output_loss: 0.6191 - val_loss: 1.0447
# Epoch 22/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8529 - attrition_output_loss: 0.3733 - department_output_accuracy: 0.7186 - department_output_loss: 0.5808 - loss: 0.9536 - val_attrition_output_accuracy: 0.8305 - val_attrition_output_loss: 0.4088 - val_department_output_accuracy: 0.6610 - val_department_output_loss: 0.6188 - val_loss: 1.0444
# Epoch 23/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8484 - attrition_output_loss: 0.3795 - department_output_accuracy: 0.6962 - department_output_loss: 0.5956 - loss: 0.9755 - val_attrition_output_accuracy: 0.8305 - val_attrition_output_loss: 0.4067 - val_department_output_accuracy: 0.6610 - val_department_output_loss: 0.6198 - val_loss: 1.0430
# Epoch 24/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8674 - attrition_output_loss: 0.3672 - department_output_accuracy: 0.7229 - department_output_loss: 0.5789 - loss: 0.9460 - val_attrition_output_accuracy: 0.8347 - val_attrition_output_loss: 0.4069 - val_department_output_accuracy: 0.6610 - val_department_output_loss: 0.6195 - val_loss: 1.0434
# Epoch 25/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - attrition_output_accuracy: 0.8650 - attrition_output_loss: 0.3675 - department_output_accuracy: 0.6807 - department_output_loss: 0.5958 - loss: 0.9635 - val_attrition_output_accuracy: 0.8305 - val_attrition_output_loss: 0.4045 - val_department_output_accuracy: 0.6610 - val_department_output_loss: 0.6200 - val_loss: 1.0411
# Epoch 26/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8702 - attrition_output_loss: 0.3587 - department_output_accuracy: 0.6912 - department_output_loss: 0.5960 - loss: 0.9540 - val_attrition_output_accuracy: 0.8347 - val_attrition_output_loss: 0.4058 - val_department_output_accuracy: 0.6653 - val_department_output_loss: 0.6192 - val_loss: 1.0423
# Epoch 27/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8838 - attrition_output_loss: 0.3473 - department_output_accuracy: 0.6985 - department_output_loss: 0.5942 - loss: 0.9413 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4013 - val_department_output_accuracy: 0.6653 - val_department_output_loss: 0.6196 - val_loss: 1.0375
# Epoch 28/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - attrition_output_accuracy: 0.8745 - attrition_output_loss: 0.3423 - department_output_accuracy: 0.7266 - department_output_loss: 0.5675 - loss: 0.9100 - val_attrition_output_accuracy: 0.8305 - val_attrition_output_loss: 0.4036 - val_department_output_accuracy: 0.6653 - val_department_output_loss: 0.6195 - val_loss: 1.0397
# Epoch 29/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - attrition_output_accuracy: 0.8710 - attrition_output_loss: 0.3476 - department_output_accuracy: 0.7089 - department_output_loss: 0.5835 - loss: 0.9311 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4029 - val_department_output_accuracy: 0.6653 - val_department_output_loss: 0.6195 - val_loss: 1.0388
# Epoch 30/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - attrition_output_accuracy: 0.8736 - attrition_output_loss: 0.3618 - department_output_accuracy: 0.6874 - department_output_loss: 0.5951 - loss: 0.9573 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4045 - val_department_output_accuracy: 0.6610 - val_department_output_loss: 0.6192 - val_loss: 1.0402
# Epoch 31/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - attrition_output_accuracy: 0.8675 - attrition_output_loss: 0.3522 - department_output_accuracy: 0.6814 - department_output_loss: 0.5989 - loss: 0.9508 - val_attrition_output_accuracy: 0.8220 - val_attrition_output_loss: 0.4052 - val_department_output_accuracy: 0.6610 - val_department_output_loss: 0.6194 - val_loss: 1.0414
# Epoch 32/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - attrition_output_accuracy: 0.8746 - attrition_output_loss: 0.3553 - department_output_accuracy: 0.7120 - department_output_loss: 0.5841 - loss: 0.9398 - val_attrition_output_accuracy: 0.8220 - val_attrition_output_loss: 0.4063 - val_department_output_accuracy: 0.6610 - val_department_output_loss: 0.6191 - val_loss: 1.0420
# Epoch 33/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - attrition_output_accuracy: 0.8803 - attrition_output_loss: 0.3259 - department_output_accuracy: 0.6942 - department_output_loss: 0.5878 - loss: 0.9134 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4063 - val_department_output_accuracy: 0.6610 - val_department_output_loss: 0.6193 - val_loss: 1.0424
# Epoch 34/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - attrition_output_accuracy: 0.8687 - attrition_output_loss: 0.3474 - department_output_accuracy: 0.6946 - department_output_loss: 0.5908 - loss: 0.9386 - val_attrition_output_accuracy: 0.8347 - val_attrition_output_loss: 0.4081 - val_department_output_accuracy: 0.6695 - val_department_output_loss: 0.6193 - val_loss: 1.0450
# Epoch 35/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - attrition_output_accuracy: 0.8705 - attrition_output_loss: 0.3483 - department_output_accuracy: 0.6914 - department_output_loss: 0.5944 - loss: 0.9422 - val_attrition_output_accuracy: 0.8305 - val_attrition_output_loss: 0.4100 - val_department_output_accuracy: 0.6695 - val_department_output_loss: 0.6204 - val_loss: 1.0488
# Epoch 36/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - attrition_output_accuracy: 0.8699 - attrition_output_loss: 0.3452 - department_output_accuracy: 0.7034 - department_output_loss: 0.5854 - loss: 0.9304 - val_attrition_output_accuracy: 0.8347 - val_attrition_output_loss: 0.4093 - val_department_output_accuracy: 0.6653 - val_department_output_loss: 0.6200 - val_loss: 1.0466
# Epoch 37/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - attrition_output_accuracy: 0.8797 - attrition_output_loss: 0.3399 - department_output_accuracy: 0.6751 - department_output_loss: 0.6040 - loss: 0.9442 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4106 - val_department_output_accuracy: 0.6653 - val_department_output_loss: 0.6206 - val_loss: 1.0499
# Epoch 38/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - attrition_output_accuracy: 0.8715 - attrition_output_loss: 0.3597 - department_output_accuracy: 0.7043 - department_output_loss: 0.5899 - loss: 0.9494 - val_attrition_output_accuracy: 0.8347 - val_attrition_output_loss: 0.4133 - val_department_output_accuracy: 0.6695 - val_department_output_loss: 0.6206 - val_loss: 1.0527
# Epoch 39/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8768 - attrition_output_loss: 0.3313 - department_output_accuracy: 0.7142 - department_output_loss: 0.5795 - loss: 0.9110 - val_attrition_output_accuracy: 0.8305 - val_attrition_output_loss: 0.4132 - val_department_output_accuracy: 0.6695 - val_department_output_loss: 0.6209 - val_loss: 1.0529
# Epoch 40/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8754 - attrition_output_loss: 0.3548 - department_output_accuracy: 0.7071 - department_output_loss: 0.5815 - loss: 0.9365 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4162 - val_department_output_accuracy: 0.6695 - val_department_output_loss: 0.6213 - val_loss: 1.0577
# Epoch 41/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8756 - attrition_output_loss: 0.3621 - department_output_accuracy: 0.6983 - department_output_loss: 0.5898 - loss: 0.9523 - val_attrition_output_accuracy: 0.8220 - val_attrition_output_loss: 0.4166 - val_department_output_accuracy: 0.6695 - val_department_output_loss: 0.6200 - val_loss: 1.0563
# Epoch 42/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8681 - attrition_output_loss: 0.3604 - department_output_accuracy: 0.6958 - department_output_loss: 0.5968 - loss: 0.9574 - val_attrition_output_accuracy: 0.8305 - val_attrition_output_loss: 0.4157 - val_department_output_accuracy: 0.6695 - val_department_output_loss: 0.6200 - val_loss: 1.0559
# Epoch 43/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8601 - attrition_output_loss: 0.3746 - department_output_accuracy: 0.6965 - department_output_loss: 0.5994 - loss: 0.9745 - val_attrition_output_accuracy: 0.8305 - val_attrition_output_loss: 0.4193 - val_department_output_accuracy: 0.6695 - val_department_output_loss: 0.6192 - val_loss: 1.0596
# Epoch 44/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8748 - attrition_output_loss: 0.3454 - department_output_accuracy: 0.7247 - department_output_loss: 0.5740 - loss: 0.9195 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4182 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6184 - val_loss: 1.0563
# Epoch 45/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8710 - attrition_output_loss: 0.3455 - department_output_accuracy: 0.7311 - department_output_loss: 0.5751 - loss: 0.9205 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4206 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6200 - val_loss: 1.0604
# Epoch 46/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8733 - attrition_output_loss: 0.3323 - department_output_accuracy: 0.6921 - department_output_loss: 0.6009 - loss: 0.9332 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4207 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6207 - val_loss: 1.0628
# Epoch 47/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8815 - attrition_output_loss: 0.3283 - department_output_accuracy: 0.7131 - department_output_loss: 0.5745 - loss: 0.9030 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4197 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6191 - val_loss: 1.0585
# Epoch 48/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8816 - attrition_output_loss: 0.3353 - department_output_accuracy: 0.6966 - department_output_loss: 0.5953 - loss: 0.9308 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4187 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6182 - val_loss: 1.0569
# Epoch 49/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8751 - attrition_output_loss: 0.3470 - department_output_accuracy: 0.6966 - department_output_loss: 0.5977 - loss: 0.9450 - val_attrition_output_accuracy: 0.8305 - val_attrition_output_loss: 0.4193 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6195 - val_loss: 1.0597
# Epoch 50/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8845 - attrition_output_loss: 0.3331 - department_output_accuracy: 0.7072 - department_output_loss: 0.5861 - loss: 0.9191 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4188 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6205 - val_loss: 1.0603
# Epoch 51/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8787 - attrition_output_loss: 0.3448 - department_output_accuracy: 0.6827 - department_output_loss: 0.6050 - loss: 0.9500 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4194 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6243 - val_loss: 1.0660
# Epoch 52/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8703 - attrition_output_loss: 0.3443 - department_output_accuracy: 0.6991 - department_output_loss: 0.5906 - loss: 0.9352 - val_attrition_output_accuracy: 0.8220 - val_attrition_output_loss: 0.4114 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6238 - val_loss: 1.0550
# Epoch 53/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8857 - attrition_output_loss: 0.3235 - department_output_accuracy: 0.7102 - department_output_loss: 0.5880 - loss: 0.9117 - val_attrition_output_accuracy: 0.8178 - val_attrition_output_loss: 0.4103 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6279 - val_loss: 1.0570
# Epoch 54/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8484 - attrition_output_loss: 0.3665 - department_output_accuracy: 0.6986 - department_output_loss: 0.5907 - loss: 0.9570 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4225 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6249 - val_loss: 1.0718
# Epoch 55/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8692 - attrition_output_loss: 0.3805 - department_output_accuracy: 0.7072 - department_output_loss: 0.5829 - loss: 0.9635 - val_attrition_output_accuracy: 0.8305 - val_attrition_output_loss: 0.4233 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6292 - val_loss: 1.0787
# Epoch 56/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8808 - attrition_output_loss: 0.3240 - department_output_accuracy: 0.7078 - department_output_loss: 0.5871 - loss: 0.9111 - val_attrition_output_accuracy: 0.8220 - val_attrition_output_loss: 0.4031 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6256 - val_loss: 1.0497
# Epoch 57/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8637 - attrition_output_loss: 0.3492 - department_output_accuracy: 0.7184 - department_output_loss: 0.5800 - loss: 0.9287 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4099 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6256 - val_loss: 1.0589
# Epoch 58/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8775 - attrition_output_loss: 0.3236 - department_output_accuracy: 0.7182 - department_output_loss: 0.5822 - loss: 0.9053 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4017 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6225 - val_loss: 1.0457
# Epoch 59/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8604 - attrition_output_loss: 0.3673 - department_output_accuracy: 0.6813 - department_output_loss: 0.6079 - loss: 0.9756 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4096 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6325 - val_loss: 1.0700
# Epoch 60/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8744 - attrition_output_loss: 0.3413 - department_output_accuracy: 0.6862 - department_output_loss: 0.6135 - loss: 0.9547 - val_attrition_output_accuracy: 0.8347 - val_attrition_output_loss: 0.4017 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6209 - val_loss: 1.0465
# Epoch 61/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8661 - attrition_output_loss: 0.3791 - department_output_accuracy: 0.7030 - department_output_loss: 0.5942 - loss: 0.9727 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.3959 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6175 - val_loss: 1.0362
# Epoch 62/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8567 - attrition_output_loss: 0.4142 - department_output_accuracy: 0.7023 - department_output_loss: 0.5933 - loss: 1.0075 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4074 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6186 - val_loss: 1.0535
# Epoch 63/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8726 - attrition_output_loss: 0.3284 - department_output_accuracy: 0.7070 - department_output_loss: 0.5900 - loss: 0.9184 - val_attrition_output_accuracy: 0.8432 - val_attrition_output_loss: 0.3976 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6243 - val_loss: 1.0478
# Epoch 64/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8736 - attrition_output_loss: 0.3368 - department_output_accuracy: 0.7205 - department_output_loss: 0.5742 - loss: 0.9110 - val_attrition_output_accuracy: 0.8305 - val_attrition_output_loss: 0.4068 - val_department_output_accuracy: 0.6610 - val_department_output_loss: 0.6313 - val_loss: 1.0620
# Epoch 65/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8661 - attrition_output_loss: 0.3303 - department_output_accuracy: 0.6950 - department_output_loss: 0.6208 - loss: 0.9509 - val_attrition_output_accuracy: 0.8432 - val_attrition_output_loss: 0.3984 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6210 - val_loss: 1.0449
# Epoch 66/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8765 - attrition_output_loss: 0.3377 - department_output_accuracy: 0.7056 - department_output_loss: 0.5895 - loss: 0.9270 - val_attrition_output_accuracy: 0.8347 - val_attrition_output_loss: 0.4007 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6181 - val_loss: 1.0431
# Epoch 67/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8523 - attrition_output_loss: 0.3767 - department_output_accuracy: 0.6966 - department_output_loss: 0.5963 - loss: 0.9732 - val_attrition_output_accuracy: 0.8432 - val_attrition_output_loss: 0.4035 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6213 - val_loss: 1.0506
# Epoch 68/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8738 - attrition_output_loss: 0.3402 - department_output_accuracy: 0.6875 - department_output_loss: 0.6048 - loss: 0.9443 - val_attrition_output_accuracy: 0.8305 - val_attrition_output_loss: 0.4081 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.7055 - val_loss: 1.1465
# Epoch 69/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8367 - attrition_output_loss: 0.3888 - department_output_accuracy: 0.6460 - department_output_loss: 0.6366 - loss: 1.0256 - val_attrition_output_accuracy: 0.8390 - val_attrition_output_loss: 0.4080 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6269 - val_loss: 1.0624
# Epoch 70/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_output_accuracy: 0.8663 - attrition_output_loss: 0.3259 - department_output_accuracy: 0.7057 - department_output_loss: 0.6003 - loss: 0.9256 - val_attrition_output_accuracy: 0.8390 - val_attrition_output_loss: 0.4279 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6187 - val_loss: 1.0756
# Epoch 71/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8508 - attrition_output_loss: 0.3680 - department_output_accuracy: 0.6643 - department_output_loss: 0.6189 - loss: 0.9871 - val_attrition_output_accuracy: 0.8347 - val_attrition_output_loss: 0.4201 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6372 - val_loss: 1.0890
# Epoch 72/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8745 - attrition_output_loss: 0.3698 - department_output_accuracy: 0.6830 - department_output_loss: 0.6248 - loss: 0.9943 - val_attrition_output_accuracy: 0.8220 - val_attrition_output_loss: 0.4123 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6176 - val_loss: 1.0532
# Epoch 73/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8529 - attrition_output_loss: 0.3463 - department_output_accuracy: 0.6911 - department_output_loss: 0.6037 - loss: 0.9500 - val_attrition_output_accuracy: 0.8305 - val_attrition_output_loss: 0.4485 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6339 - val_loss: 1.1176
# Epoch 74/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8714 - attrition_output_loss: 0.3621 - department_output_accuracy: 0.7089 - department_output_loss: 0.5840 - loss: 0.9464 - val_attrition_output_accuracy: 0.8432 - val_attrition_output_loss: 0.4272 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6236 - val_loss: 1.0787
# Epoch 75/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8595 - attrition_output_loss: 0.3886 - department_output_accuracy: 0.6939 - department_output_loss: 0.5998 - loss: 0.9883 - val_attrition_output_accuracy: 0.8220 - val_attrition_output_loss: 0.4106 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6307 - val_loss: 1.0653
# Epoch 76/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8525 - attrition_output_loss: 0.3917 - department_output_accuracy: 0.7023 - department_output_loss: 0.5960 - loss: 0.9874 - val_attrition_output_accuracy: 0.8305 - val_attrition_output_loss: 0.4415 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.7061 - val_loss: 1.1867
# Epoch 77/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8510 - attrition_output_loss: 0.3521 - department_output_accuracy: 0.6695 - department_output_loss: 0.6220 - loss: 0.9743 - val_attrition_output_accuracy: 0.8220 - val_attrition_output_loss: 0.4133 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6280 - val_loss: 1.0648
# Epoch 78/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8432 - attrition_output_loss: 0.3909 - department_output_accuracy: 0.6965 - department_output_loss: 0.5985 - loss: 0.9893 - val_attrition_output_accuracy: 0.8305 - val_attrition_output_loss: 0.4148 - val_department_output_accuracy: 0.5932 - val_department_output_loss: 0.6461 - val_loss: 1.0854
# Epoch 79/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8561 - attrition_output_loss: 0.3749 - department_output_accuracy: 0.6463 - department_output_loss: 0.6313 - loss: 1.0062 - val_attrition_output_accuracy: 0.8347 - val_attrition_output_loss: 0.4388 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6167 - val_loss: 1.0884
# Epoch 80/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8479 - attrition_output_loss: 0.3820 - department_output_accuracy: 0.7176 - department_output_loss: 0.5755 - loss: 0.9579 - val_attrition_output_accuracy: 0.8390 - val_attrition_output_loss: 0.4327 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6183 - val_loss: 1.0828
# Epoch 81/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8413 - attrition_output_loss: 0.4282 - department_output_accuracy: 0.6909 - department_output_loss: 0.6045 - loss: 1.0324 - val_attrition_output_accuracy: 0.8305 - val_attrition_output_loss: 0.4177 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6325 - val_loss: 1.0827
# Epoch 82/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8346 - attrition_output_loss: 0.4157 - department_output_accuracy: 0.6702 - department_output_loss: 0.6129 - loss: 1.0288 - val_attrition_output_accuracy: 0.8220 - val_attrition_output_loss: 0.4751 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6655 - val_loss: 1.1822
# Epoch 83/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8469 - attrition_output_loss: 0.3972 - department_output_accuracy: 0.6773 - department_output_loss: 0.6318 - loss: 1.0286 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4248 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6445 - val_loss: 1.1032
# Epoch 84/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8522 - attrition_output_loss: 0.3632 - department_output_accuracy: 0.6441 - department_output_loss: 0.6488 - loss: 1.0124 - val_attrition_output_accuracy: 0.8220 - val_attrition_output_loss: 0.4464 - val_department_output_accuracy: 0.5890 - val_department_output_loss: 0.6595 - val_loss: 1.1337
# Epoch 85/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - attrition_output_accuracy: 0.8217 - attrition_output_loss: 0.4233 - department_output_accuracy: 0.6281 - department_output_loss: 0.6214 - loss: 1.0451 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4345 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.7668 - val_loss: 1.2459
# Epoch 86/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8455 - attrition_output_loss: 0.4109 - department_output_accuracy: 0.6450 - department_output_loss: 0.6939 - loss: 1.1046 - val_attrition_output_accuracy: 0.8347 - val_attrition_output_loss: 0.4245 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6233 - val_loss: 1.0761
# Epoch 87/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8456 - attrition_output_loss: 0.4185 - department_output_accuracy: 0.7014 - department_output_loss: 0.6065 - loss: 1.0251 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4381 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6215 - val_loss: 1.0936
# Epoch 88/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8416 - attrition_output_loss: 0.4039 - department_output_accuracy: 0.6707 - department_output_loss: 0.6189 - loss: 1.0228 - val_attrition_output_accuracy: 0.8220 - val_attrition_output_loss: 0.4695 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6263 - val_loss: 1.1316
# Epoch 89/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8515 - attrition_output_loss: 0.4011 - department_output_accuracy: 0.6944 - department_output_loss: 0.6173 - loss: 1.0183 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4231 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6173 - val_loss: 1.0695
# Epoch 90/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - attrition_output_accuracy: 0.8418 - attrition_output_loss: 0.4054 - department_output_accuracy: 0.6344 - department_output_loss: 0.6589 - loss: 1.0642 - val_attrition_output_accuracy: 0.8305 - val_attrition_output_loss: 0.4269 - val_department_output_accuracy: 0.4576 - val_department_output_loss: 0.7150 - val_loss: 1.1666
# Epoch 91/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - attrition_output_accuracy: 0.8332 - attrition_output_loss: 0.4444 - department_output_accuracy: 0.5604 - department_output_loss: 0.6781 - loss: 1.1227 - val_attrition_output_accuracy: 0.8220 - val_attrition_output_loss: 0.4490 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6220 - val_loss: 1.1063
# Epoch 92/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - attrition_output_accuracy: 0.8308 - attrition_output_loss: 0.4209 - department_output_accuracy: 0.6359 - department_output_loss: 0.6624 - loss: 1.0836 - val_attrition_output_accuracy: 0.8220 - val_attrition_output_loss: 0.4410 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6885 - val_loss: 1.1710
# Epoch 93/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8424 - attrition_output_loss: 0.4102 - department_output_accuracy: 0.6539 - department_output_loss: 0.6144 - loss: 1.0246 - val_attrition_output_accuracy: 0.8263 - val_attrition_output_loss: 0.4158 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6841 - val_loss: 1.1353
# Epoch 94/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - attrition_output_accuracy: 0.8635 - attrition_output_loss: 0.3755 - department_output_accuracy: 0.7065 - department_output_loss: 0.5870 - loss: 0.9623 - val_attrition_output_accuracy: 0.8220 - val_attrition_output_loss: 0.4381 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6182 - val_loss: 1.0869
# Epoch 95/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8445 - attrition_output_loss: 0.4033 - department_output_accuracy: 0.6726 - department_output_loss: 0.6116 - loss: 1.0148 - val_attrition_output_accuracy: 0.8220 - val_attrition_output_loss: 0.4262 - val_department_output_accuracy: 0.4492 - val_department_output_loss: 0.7219 - val_loss: 1.1696
# Epoch 96/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - attrition_output_accuracy: 0.8270 - attrition_output_loss: 0.4210 - department_output_accuracy: 0.6486 - department_output_loss: 0.6553 - loss: 1.0768 - val_attrition_output_accuracy: 0.8178 - val_attrition_output_loss: 0.5156 - val_department_output_accuracy: 0.6314 - val_department_output_loss: 0.6403 - val_loss: 1.1898
# Epoch 97/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - attrition_output_accuracy: 0.8478 - attrition_output_loss: 0.3937 - department_output_accuracy: 0.6698 - department_output_loss: 0.6212 - loss: 1.0137 - val_attrition_output_accuracy: 0.8136 - val_attrition_output_loss: 0.4339 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6303 - val_loss: 1.0973
# Epoch 98/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - attrition_output_accuracy: 0.8385 - attrition_output_loss: 0.4285 - department_output_accuracy: 0.6846 - department_output_loss: 0.6522 - loss: 1.0810 - val_attrition_output_accuracy: 0.8220 - val_attrition_output_loss: 0.5346 - val_department_output_accuracy: 0.3983 - val_department_output_loss: 0.8370 - val_loss: 1.4000
# Epoch 99/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - attrition_output_accuracy: 0.8396 - attrition_output_loss: 0.4518 - department_output_accuracy: 0.5812 - department_output_loss: 0.8013 - loss: 1.2537 - val_attrition_output_accuracy: 0.8093 - val_attrition_output_loss: 0.6145 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6203 - val_loss: 1.2786
# Epoch 100/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - attrition_output_accuracy: 0.8485 - attrition_output_loss: 0.4414 - department_output_accuracy: 0.6611 - department_output_loss: 0.6420 - loss: 1.0839 - val_attrition_output_accuracy: 0.8136 - val_attrition_output_loss: 0.4398 - val_department_output_accuracy: 0.6737 - val_department_output_loss: 0.6873 - val_loss: 1.1662

# %%
# Evaluate the model with the testing data
y_test_targets = {
    'attrition_output': y_test['Attrition'].apply(lambda x: 1 if x == 'Yes' else 0),  # Convert Yes/No to 1/0
    'department_output': y_test_department_encoded_df
}
evaluation_results = model.evaluate(
    X_test_scaled,
    y_test_targets,
    verbose=1
)
evaluation_results
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - attrition_output_accuracy: 0.8502 - attrition_output_loss: 0.3721 - department_output_accuracy: 0.6917 - department_output_loss: 0.6444 - loss: 1.0169
# [0.9936051964759827,
#  0.3589197099208832,
#  0.6320303678512573,
#  0.8639456033706665,
#  0.7108843326568604]

# %%
# Print the accuracy for both department and attrition
attrition_accuracy = evaluation_results[3]
department_accuracy = evaluation_results[4]
print(f"Attrition Accuracy: {attrition_accuracy}")
print(f"Department Accuracy: {department_accuracy}")
# Out:
# Attrition Accuracy: 0.8639456033706665
# Department Accuracy: 0.7108843326568604

# %% [markdown]
# # Summary
#
# In the provided space below, briefly answer the following questions.
#
# 1. Is accuracy the best metric to use on this data? Why or why not?
#
# 2. What activation functions did you choose for your output layers, and why?
#
# 3. Can you name a few ways that this model might be improved?

# %% [markdown]
# YOUR ANSWERS HERE
#
# 1. Accuracy can be a good baseline metric to measure data results but should be evaluated with caution. If the data is imbalanced than accuracy can be a misleading metric.
# 2. For the Attrition output I used a sigmoid activation because it was a binary classification problem. For the Department output I used softmax because it is multiclass.
# 3. Two things that come to mind first are experiment with hyperparameter tuning changing number of layers and neurons in the model. Secondly, you could preprocess the data a little more with some feature engineering. Doing these things could have a positive impact on the models results.
